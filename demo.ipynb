# %%
# !pip install -qU transformers accelerate einops langchain xformers bitsandbytes faiss-gpu sentence_transformers pypdf unstructured
# !git clone https://github.com/phanhoang1803/QA_Generator.git

# %cd QA_Generator
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.4/7.4 MB 36.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 244.2/244.2 kB 24.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.2/42.2 kB 3.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 49.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 109.1/109.1 MB 8.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 92.6/92.6 MB 8.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.5/85.5 MB 7.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.0/86.0 kB 8.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 270.3/270.3 kB 24.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 49.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 268.8/268.8 kB 23.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 116.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 78.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 90.0/90.0 kB 13.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 72.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.4/49.4 kB 6.3 MB/s eta 0:00:00
#   Building wheel for sentence_transformers (setup.py) ... done
# Cloning into 'QA_Generator'...
# remote: Enumerating objects: 84, done.
# remote: Counting objects: 100% (84/84), done.
# remote: Compressing objects: 100% (60/60), done.
# remote: Total 84 (delta 40), reused 60 (delta 19), pack-reused 0
# Receiving objects: 100% (84/84), 3.83 MiB | 3.49 MiB/s, done.
# Resolving deltas: 100% (40/40), done.
# /content/QA_Generator

# %%
# %cd /content
# !git clone https://github.com/phanhoang1803/QA_Generator.git
# %cd QA_Generator
# Out:
# /content
# Cloning into 'QA_Generator'...
# remote: Enumerating objects: 93, done.
# remote: Counting objects: 100% (93/93), done.
# remote: Compressing objects: 100% (68/68), done.
# remote: Total 93 (delta 46), reused 64 (delta 20), pack-reused 0
# Receiving objects: 100% (93/93), 3.83 MiB | 28.86 MiB/s, done.
# Resolving deltas: 100% (46/46), done.
# /content/QA_Generator

# %%
model_id = 'meta-llama/Llama-2-7b-chat-hf'
hf_auth = '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'

# %%
from models import LLAMAModel

model = LLAMAModel(model_id, hf_auth)
llm = model.load_llm(temperature=0.3, max_new_tokens=1024)
# Out:
# Downloading (…)lve/main/config.json:   0%|          | 0.00/614 [00:00<?, ?B/s]
# /usr/local/lib/python3.10/dist-packages/transformers/modeling_utils.py:2193: FutureWarning: The `use_auth_token` argument is deprecated and will be removed in v5 of Transformers.
#   warnings.warn(
# Downloading (…)fetensors.index.json:   0%|          | 0.00/26.8k [00:00<?, ?B/s]
# Downloading shards:   0%|          | 0/2 [00:00<?, ?it/s]
# Downloading (…)of-00002.safetensors:   0%|          | 0.00/9.98G [00:00<?, ?B/s]
# Downloading (…)of-00002.safetensors:   0%|          | 0.00/3.50G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# Downloading (…)neration_config.json:   0%|          | 0.00/188 [00:00<?, ?B/s]
# Model loaded on cuda:0
# Downloading (…)okenizer_config.json:   0%|          | 0.00/776 [00:00<?, ?B/s]
# /usr/local/lib/python3.10/dist-packages/transformers/tokenization_utils_base.py:1714: FutureWarning: The `use_auth_token` argument is deprecated and will be removed in v5 of Transformers.
#   warnings.warn(
# Downloading tokenizer.model:   0%|          | 0.00/500k [00:00<?, ?B/s]
# Downloading (…)/main/tokenizer.json:   0%|          | 0.00/1.84M [00:00<?, ?B/s]
# Downloading (…)cial_tokens_map.json:   0%|          | 0.00/414 [00:00<?, ?B/s]

# %%
import QA_Generator

chain = QA_Generator.load_chain(llm=llm, courseID=1, pdf_path="/content/QA_Generator/data/course2/SurveyOfLLMs.pdf")
# Out:
# Downloading (…)a8e1d/.gitattributes:   0%|          | 0.00/1.18k [00:00<?, ?B/s]
# Downloading (…)_Pooling/config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
# Downloading (…)b20bca8e1d/README.md:   0%|          | 0.00/10.6k [00:00<?, ?B/s]
# Downloading (…)0bca8e1d/config.json:   0%|          | 0.00/571 [00:00<?, ?B/s]
# Downloading (…)ce_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# Downloading (…)e1d/data_config.json:   0%|          | 0.00/39.3k [00:00<?, ?B/s]
# Downloading pytorch_model.bin:   0%|          | 0.00/438M [00:00<?, ?B/s]
# Downloading (…)nce_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# Downloading (…)cial_tokens_map.json:   0%|          | 0.00/239 [00:00<?, ?B/s]
# Downloading (…)a8e1d/tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# Downloading (…)okenizer_config.json:   0%|          | 0.00/363 [00:00<?, ?B/s]
# Downloading (…)8e1d/train_script.py:   0%|          | 0.00/13.1k [00:00<?, ?B/s]
# Downloading (…)b20bca8e1d/vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# Downloading (…)bca8e1d/modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]

# %%
chat_history = []

# query = "Please create questions that follow the same structure as Bloom's Taxonomy for each level."
query = "Please create a set of multiple choice questions that follow the Bloom's Taxonomy and also the correct answer for each question. And for each level, please provide two questions."
result = chain({"question": query, "chat_history": chat_history})

print(result['answer'])
# Out:
#  Sure! Here are some sample questions based on the information provided in the passage:
# Level 1 - Remembering:
# Question 1: What are the three fundamental parts of the VietAI system?
# A) Teaching, Research, and Community
# B) Dataset, Feature Selection, and Machine Learning Models
# C) Foundation of Deep Learning, Topic-focused Courses, and Advances in Computer Vision and Natural Language Processing
# Answer: A) Teaching, Research, and Community
#
# Question 2: According to the passage, what is the purpose of the VietAI system?
# A) To provide comprehensive knowledge of deep learning techniques
# B) To offer topic-focused courses on various machine learning models
# C) To create a large and diverse dataset for training machine learning models
# Answer: B) To offer topic-focused courses on various machine learning models
#
# Level 2 - Understanding:
# Question 1: What are the two main areas of focus in the VietAI system?
# A) Computer Vision and Natural Language Processing
# B) Machine Learning and Deep Learning
# C) Feature Selection and Problem Solving
# Answer: A) Computer Vision and Natural Language Processing
#
# Question 2: How does Dr. Hung Bui describe the applications of computer vision?
# A) As a way for machines to perceive and understand visual information
# B) As a tool for analyzing and interpreting data
# C) As a means of enhancing human intelligence
# Answer: A) As a way for machines to perceive and understand visual information
#
# Level 3 - Applying:
# Question 1: What are some of the applications of computer vision according to Dr. Hung Bui?
# A) Image recognition and classification
# B) Object detection and tracking
# C) Image segmentation and analysis
# Answer: A) Image recognition and classification
#
# Question 2: Can the VietAI system be used for natural language processing tasks?
# A) Yes, it can be used for neural machine translation, text summarization, and question answering
# B) No, it is only useful for computer vision tasks
# Answer: A) Yes, it can be used for neural machine translation, text summarization, and question answering
#
# Level 4 - Analyzing:
# Question 1: What are some of the key features of the VietAI system?
# A) Its ability to handle complex tasks and large datasets
# B) Its focus on practical applications and real-world problems
# C) Its emphasis on interdisciplinary approaches to machine learning
# Answer: B) Its focus on practical applications and real-world problems
#
# Question 2: How does the VietAI system differ from other machine learning systems?
# A) It has a more comprehensive approach to machine learning
# B) It places greater emphasis on theoretical foundations
# C) It offers more specialized courses on advanced topics
# Answer: B) It places greater emphasis on practical applications and real-world problems
#
# Level 5 - Evaluating:
# Question 1: How effective is the VietAI system in solving real-world problems?
# A) Very effective, as demonstrated by its success in various applications
# B) Somewhat effective, but with room for improvement
# C) Ineffective, as it lacks practical relevance or theoretical foundation
# Answer: A) Very effective, as demonstrated by its success in various applications
#
# Question 2: How does the VietAI system compare to other machine learning systems in terms of its ability to solve complex problems?
# A) It is significantly better than other systems in this regard
# B) It is comparable to other systems in terms of its ability to solve complex problems
# C) It falls short of other systems in this regard
# Answer: A) It is significantly better than other systems in this regard

# %%
chat_history = []

# query = "Please create questions that follow the same structure as Bloom's Taxonomy for each level."
query = "Please create a set of multiple choice questions that follow the Bloom's Taxonomy and also the correct answer for each question. And for each level, please provide two questions."
result = chain({"question": query, "chat_history": chat_history})

print(result['answer'])
# Out:
#  Sure! Here are some sample questions and answers based on the provided list of models:
# Level 1: Remembering
# Question 1: What is the name of the largest language model released in 2020?
# A) GPT-3
# B) Codex
# C) GShard
# D) ERNIE 3.0
# Answer: A) GPT-3
#
# Question 2: Which model has the highest number of parameters among the ones listed?
# A) GPT-3
# B) Codex
# C) GShard
# D) HyperlCLOVA
# Answer: C) GShard
#
# Level 2: Understanding
# Question 1: What is the main difference between GPT-3 and GShard?
# A) GPT-3 uses more data to train
# B) GShard uses more powerful hardware to train
# C) GPT-3 has more layers than GShard
# D) GShard has more parameters than GPT-3
# Answer: B) GShard uses more powerful hardware to train
#
# Question 2: How many tokens does LLaMA have in its training dataset?
# A) 100 million
# B) 1 billion
# C) 10 billion
# D) 1 trillion
# Answer: B) 1 billion
#
# Level 3: Applying Knowledge
# Question 1: What is the name of the model that achieved the highest score on the OPT-IML benchmark?
# A) GPT-3
# B) Codex
# C) GShard
# D) Opt-IML
# Answer: D) Opt-IML
#
# Question 2: Which model has the highest F1 score on the BLOOMZ benchmark?
# A) GPT-3
# B) CodeGeeX
# C) LLaMA
# D) Yuan 1.0
# Answer: A) GPT-3
#
# Level 4: Analyzing and Evaluating
# Question 1: What is the main advantage of using a large language model like GPT-3 for question answering?
# A) It can generate more accurate answers
# B) It can handle complex questions better
# C) It can provide more diverse answers
# D) It can be fine-tuned for specific tasks
# Answer: A) It can generate more accurate answers
#
# Question 2: How does the performance of a language model on a benchmark like BLOOMZ relate to its performance on a different task like open-book QA?
# A) They are directly related
# B) There is no relationship
# C) The performance depends on the specific task
# D) The performance is inverse to the task
# Answer: C) The performance depends on the specific task
#
# Please let me know if you need anything else!
